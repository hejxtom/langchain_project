# %% [markdown]
# # 调用线上的大模型
#
# ## 1. 调用具体模型厂商的API
#
# ### 1.1 调用DeepSeek官网的DeepSeek模型
#
# 调用大模型涉及到三个特别重要的参数：
# base_url、model_name、api_key
#
# 举例1:将参数信息存储在.env配置文件中

# %%
import os

from dotenv import load_dotenv
from langchain_deepseek import ChatDeepSeek

# 1、读取.env配置文件中的信息。相关的环境变量以.env文件中的优先
load_dotenv(override=True)

DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

# 2、模型的初始化
llm_deepseek = ChatDeepSeek(
    model="deepseek-v4-flash",
    api_key=DEEPSEEK_API_KEY,
    api_base=DEEPSEEK_BASE_URL,
)

# 3、模型的调用
response= llm_deepseek.invoke("请用一句话介绍你自己")
print(response)

# %% [markdown]
# 举例2：是对举例1的优化

# %%
import os

from dotenv import load_dotenv
from langchain_deepseek import ChatDeepSeek

# 1、读取.env配置文件中的信息。相关的环境变量以.env文件中的优先
load_dotenv(override=True)

# DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
# DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

# 2、模型的初始化
llm_deepseek = ChatDeepSeek(
    model="deepseek-v4-flash",
    # api_key=DEEPSEEK_API_KEY,
    # api_base=DEEPSEEK_BASE_URL,
)

# 3、模型的调用
response= llm_deepseek.invoke("请用一句话介绍你自己")
print(response)

# %% [markdown]
# 举例3：演示一下参数声明在代码中（不推荐）

# %%
from langchain_deepseek import ChatDeepSeek

# 模型的初始化
llm_deepseek = ChatDeepSeek(
    model="deepseek-v4-flash",
    api_key="sk-01323021c664464b8a4187d9444259f7",
    api_base="https://api.deepseek.com",
)

# 模型的调用
response= llm_deepseek.invoke("请用一句话介绍你自己")
print(response)

# %% [markdown]
# ### 1.2 通过智谱平台获取相关的大模型
#
# 举例

# %%
from langchain_community.chat_models import ChatZhipuAI
import os

from dotenv import load_dotenv

# 1、读取.env配置文件中的信息。相关的环境变量以.env文件中的优先
load_dotenv(override=True)

# ZHIPUAI_API_KEY = os.getenv("ZHIPUAI_API_KEY")
# ZHPPUAI_BASE_URL = os.getenv("ZHPPUAI_BASE_URL")

# 2、模型的初始化
llm_zhipu = ChatZhipuAI(
    model="glm-5.1",
    # api_key=ZHIPUAI_API_KEY,
    # api_base=ZHPPUAI_BASE_URL,
)

# 3、模型的调用
response= llm_zhipu.invoke("请用一句话介绍你自己")
print(response)

# %% [markdown]
# ### 1.3 通过阿里云百炼平台获取相关的大模型
#
# 举例

# %%
from langchain_community.chat_models import ChatTongyi
from dotenv import load_dotenv

# 1、读取.env配置文件中的信息。相关的环境变量以.env文件中的优先
load_dotenv(override=True)

# DASHSCOPE_API_KEY = os.getenv("DASHSCOPE_API_KEY")

# 2、模型的初始化
llm_tongyi = ChatTongyi(
    model="qwen3-max",
    # api_key=DASHSCOPE_API_KEY,
)

# 3、模型的调用
response= llm_tongyi.invoke("请用一句话介绍你自己")
print(response)

# %% [markdown]
# ## 2. 兼容的写法
#
# 使用ChatOpenAI
#
# 举例1：调用deepseek官网提供的大模型

# %%
from langchain_openai import ChatOpenAI

# 加载配置文件
load_dotenv(override=True)

DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

# 获取大模型
model = ChatOpenAI(
    model="deepseek-v4-flash",
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
)

print(model.invoke("1 + 1 = ？"))

# %% [markdown]
# 举例2：调用智谱平台的大模型

# %%
from langchain_openai import ChatOpenAI

# 加载配置文件
load_dotenv(override=True)

ZHIPUAI_API_KEY = os.getenv("ZHIPUAI_API_KEY")
ZHPPUAI_BASE_URL = os.getenv("ZHPPUAI_BASE_URL")

# 获取大模型
model = ChatOpenAI(
    model="glm-5.1",
    api_key=ZHIPUAI_API_KEY,
    base_url=ZHPPUAI_BASE_URL,
)

print(model.invoke("1 + 1 = ？"))

# %% [markdown]
# ## 3. 使用中转平台
#
# ### 3.1 使用OpenRouter
#
# 举例1：调用的国内的大模型。比如Deepseek

# %%
from langchain_openrouter import ChatOpenRouter
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")
OPENROUTER_API_BASE = os.getenv("OPENROUTER_API_BASE")

# 获取大模型
model = ChatOpenRouter(
    model="deepseek/deepseek-v4-flash",
    api_key=OPENROUTER_API_KEY,
    base_url=OPENROUTER_API_BASE,
)

print(model.invoke("一句话介绍下你自己"))

# %% [markdown]
# 举例2：调用国外的大模型。比如gpt

# %%
from langchain_openrouter import ChatOpenRouter
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

# OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")
# OPENROUTER_API_BASE = os.getenv("OPENROUTER_API_BASE")

# 获取大模型
model = ChatOpenRouter(
    model="openai/gpt-4o-mini",
    # api_key=OPENROUTER_API_KEY,
    # base_url=OPENROUTER_API_BASE,
)

print(model.invoke("一句话介绍下你自己"))

# %% [markdown]
# ### 3.2 使用CloseAI平台
#
# 举例1：调用国内的大模型。比如deepseek

# %%
from langchain_openai import ChatOpenAI
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
CLOSEAI_BASE_URL = os.getenv("CLOSEAI_BASE_URL")

# 获取大模型
model = ChatOpenAI(
    model="deepseek-v4-flash",
    api_key=CLOSEAI_API_KEY,
    base_url=CLOSEAI_BASE_URL,
)

print(model.invoke("一句话介绍下你自己"))

# %% [markdown]
# 举例2：调用国外的大模型。比如：gpt

# %%
from langchain_openai import ChatOpenAI
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
CLOSEAI_BASE_URL = os.getenv("CLOSEAI_BASE_URL")

# 获取大模型
model = ChatOpenAI(
    model="gpt-5.4-mini",
    api_key=CLOSEAI_API_KEY,
    base_url=CLOSEAI_BASE_URL,
)

print(model.invoke("一句话介绍下你自己"))

# %% [markdown]
# ## 4. 使用LangChain1.x的统一方式
#
# 使用 init_chat_model()
#
# 举例1：调用DeepSeek官网的DeepSeek模型

# %%
from langchain.chat_models import init_chat_model
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

# 获取大模型
model = init_chat_model(
    # model="deepseek-v4-flash",
    # model_provider="deepseek",
    # 或者
    model="deepseek:deepseek-v4-flash",
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
)

print(model.invoke("一句话介绍下你自己"))

# %% [markdown]
# 举例2：调用CloseAI平台的大模型

# %%
from langchain.chat_models import init_chat_model
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
CLOSEAI_BASE_URL = os.getenv("CLOSEAI_BASE_URL")

# 获取大模型
model = init_chat_model(
    model="deepseek-v4-flash",
    model_provider='openai',
    api_key=CLOSEAI_API_KEY,
    base_url=CLOSEAI_BASE_URL,
)

print(model.invoke("一句话介绍下你自己"))
# Out:
# content='我是DeepSeek，一个由深度求索公司创造的AI助手，乐于免费帮你解答问题、处理文件、进行深度对话，拥有1M超长上下文记忆。' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 119, 'prompt_tokens': 8, 'total_tokens': 127, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 81, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': None, 'id': 'chatcmpl-fafd6bed-eef5-9ee1-acc3-1965bfdf2bd9', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f8dc4-918b-7973-bffa-fb1c565b4058-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 8, 'output_tokens': 119, 'total_tokens': 127, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 81}}

# %% [markdown]
# 举例3：

# %%
from langchain.chat_models import init_chat_model
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
CLOSEAI_BASE_URL = os.getenv("CLOSEAI_BASE_URL")

# 获取大模型
model = init_chat_model(
    model="openai:gpt-5.4-mini",
    api_key=CLOSEAI_API_KEY,
    base_url=CLOSEAI_BASE_URL,
)

print(model.invoke("一句话介绍下你自己"))

# %% [markdown]
# ## 5. 小结
#
# DeepSeek官网的DeepSeek模型：ChatDeepSeek() 、 ChatOpenAI() 、 init_chat_model()
#
# 阿里云百炼平台的DeepSeek模型：ChatTongyi() 、ChatOpenAI() 、 init_chat_model()
#
# OpenRouter平台的DeepSeek模型：ChatOpenRouter() 、 ChatOpenAI()、init_chat_model()
#
# CloseAI平台的DeepSeek模型：ChatOpenAI()、init_chat_model()
